# %%
import random 
import matplotlib.pyplot as plt

# %%
categorias =["a","b","c","d"]
valores_aleatorios =[]

for i in range(len(categorias)):
    numero_azar = random.randint(1,100)
    valores_aleatorios.append(valores_aleatorios)

plt.bar(categorias, valores_aleatorios, color=["orange", "red", "yellow", "blue"])

plt.tittle("Grafico de barras con datos aleatorios")
plt.xlabel("categorias")
plt.ylabel("valores_aleatorios")
plt.show()

# %%
frutas = ["manzanas", "peras"]
numero_frutas = []

for i in range(len(frutas)):
    cantidad = random.randint(1,100)
    numero_frutas.append(cantidad)


plt.bar(frutas, numero_frutas, color=["orange", "blue"])
plt.title("Frutas del mercado")
plt.xlabel("frutas")
plt.ylabel("numero frutas")
plt.show()
